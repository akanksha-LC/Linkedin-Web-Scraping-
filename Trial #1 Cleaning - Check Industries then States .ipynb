# %%
import pandas as pd
import numpy as np

# %%
linkRaw1000 = pd.read_csv('linkRaw1000.csv')

# %%
print(linkRaw1000['Followers'].isnull().values.any())
print(linkRaw1000['Location'].isnull().values.any())
print(linkRaw1000['Industry'].isnull().values.any()) #bigFatLie
# Out:
# True
# False
# False

# %%
for x in range(len(linkRaw1000)):
    if(pd.isnull(linkRaw1000.Followers[x])):
        linkRaw1000.Followers[x] = linkRaw1000.Location[x]
        linkRaw1000.Location[x] = np.NaN
# Out:
# C:\Users\chattoa\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chattoa\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
linkRaw1000['Followers'].isnull().values.any()
# Out:
# False

# %%
linkRaw1000['Location'].isnull().values.any()
# Out:
# True

# %%
linkRaw1000['Industry'].isnull().values.any() #bigfatLIE
# Out:
# False

# %%
nan_loc = linkRaw1000[linkRaw1000.isna().any(axis=1)]
nan_loc.tail(10)
# Out:
#      Unnamed: 0                       Company                  Industry  \
# 929         929        Wayne State University               Detroit, mi
# 930         930      The University of Kansas              Lawrence, KS
# 931         931          Full Sail University           Winter Park, fl
# 932         932              UC Santa Barbara         Santa Barbara, CA
# 935         935              Brown University  Providence, Rhode Island
# 936         936  The University of New Mexico           Albuquerque, nm
# 948         948                       Technip              Oil & Energy
# 971         971                      Engadget              Online Media
# 976         976                  Alstom Power              Oil & Energy
# 983         983                           NHS    Hospital & Health Care
#
#     Location       Followers
# 929      NaN  181K followers
# 930      NaN  186K followers
# 931      NaN  120K followers
# 932      NaN  208K followers
# ...

# %%
states_Cab = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
states_Cnames = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", "Wisconsin", "West Virginia", "Wyoming"]
states_NCab = [x.lower() for x in states_Cab]
states_NCnames = [x.lower() for x in states_Cnames]
states_list = states_Cab + states_Cnames + states_NCab + states_NCnames

# %%
indx = 0 
list1 = linkRaw1000['Industry']
list2 = linkRaw1000['Location']
for x in list1:
    temp_statelist = x.split(' ')
    if(len(temp_statelist) == 3):
        for state in states_list:
            if(temp_statelist[2]==state):
                list2[list1.index(x)] = x
                list1[list1.index(x)] = np.NaN
#list1[list1.index(x)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-6885ed2641f1> in <module>
#       8             if(temp_statelist[2]==state):
#       9                 #list2[list1.index(x)] = x
# ---> 10                 list1[list1.index(x)] = np.NaN
#      11 #list1[list1.index(x)]
#
# TypeError: 'RangeIndex' object is not callable

# %%
for x in linkRaw1000['Industry']:
    print(x)
    print(linkRaw1000['Industry'][[linkRaw1000['Industry'].index(x)]])
# Out:
# Consumer Electronics
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-1f55fb1d9450> in <module>
#       1 for x in linkRaw1000['Industry']:
#       2     print(x)
# ----> 3     print(linkRaw1000['Industry'][[linkRaw1000['Industry'].index(x)]])
#
# TypeError: 'RangeIndex' object is not callable

# %%
test_string = 'Boulder, Colorado'
x = test_string.split(', ')
print(x)
col = 'Colorado'
if(x[1]==col):
    print('true')
#list1 = ['lola']
#list2 = ['i love you','kk',""]
#list3 = ['i love you','kk',""]
#st1 = "love"
#st2 = 'love'
#if(st1==st2):
    #print('true')
# Out:
# ['Boulder', 'Colorado']
# true

# %%
linkRaw1000.tail(60)
# Out:
#      Unnamed: 0                               Company  \
# 935         935                      Brown University
# 936         936          The University of New Mexico
# 937         937                               Philips
# 938         938                         The Economist
# 939         939                      HCL Technologies
# 940         940                                   BBC
# 941         941                                   DHL
# 942         942                           Weatherford
# 943         943                           AstraZeneca
# 944         944                              Emirates
# 945         945               Standard Chartered Bank
# 946         946                                   H&M
# 947         947                                  IKEA
# 948         948                               Technip
# 949         949                                Worley
# 950         950                                  KPMG
# ...

# %%
indx = -1
for x in linkRaw1000['Industry']:
    indx += 1
    if isinstance(x, float):
        print(x)
    else:
        #print(x)
        temp_statelist = x.split(' ')
        #print('true')
        if(len(temp_statelist) == 3):
            #print('true1')
            for state in states_list:
                print(temp_statelist[2], state)
                if(temp_statelist[2]==state):
                    print('jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj')
                    linkRaw1000.Location[indx] = x
                    print('what am i doing')
                    linkRaw1000.Industry[indx] = np.NaN
                    
#print(linkRaw1000.iloc[935])
# Out:
#  AL
#  AK
#  AZ
#  AR
#  CA
#  CO
#  CT
#  DC
#  DE
#  FL
#  GA
#  HI
#  ID
#  IL
#  IN
#  IA
#  KS
#  KY
#  LA
#  ME
#  MD
#  MA
#  MI
#  MN
#  MS
#  MO
#  MT
#  NE
#  NV
#  NH
#  NJ
#  NM
#  NY
#  NC
#  ND
#  OH
#  OK
#  OR
#  PA
#  RI
#  SC
#  SD
#  TN
#  TX
#  UT
#  VT
#  VA
#  WA
#  WV
#  WI
#  WY
#  Alaska
#  Alabama
#  Arkansas
#  American Samoa
#  Arizona
#  California
#  Colorado
#  Connecticut
#  District
#  of Columbia
#  Delaware
#  Florida
#  Georgia
#  Guam
#  Hawaii
#  Iowa
#  Idaho
#  Illinois
#  Indiana
#  Kansas
#  Kentucky
#  Louisiana
#  Massachusetts
#  Maryland
#  Maine
#  Michigan
#  Minnesota
#  Missouri
#  Mississippi
#  Montana
#  North Carolina
#  North Dakota
#  Nebraska
#  New Hampshire
#  New Jersey
#  New Mexico
#  Nevada
#  New York
#  Ohio
#  Oklahoma
#  Oregon
#  Pennsylvania
#  Puerto Rico
#  Rhode Island
#  South Carolina
#  South Dakota
#  Tennessee
#  Texas
#  Utah
#  Virginia
#  Virgin Islands
#  Vermont
#  Washington
#  Wisconsin
# ...

# %%
pd.value_counts(linkRaw1000['Industry']).tail(50)
# Out:
# Law Practice                           1
# Atlanta, GA                            1
# Chicago, IL                            1
# Management Consulting                  1
# Cambridge, Massachusetts               1
# Seattle, wa                            1
# Blacksburg, VA                         1
# Morgantown, wv                         1
# Madison, WI                            1
# Motion Pictures & Film                 1
# Business Supplies & Equipment          1
# Boston, ma                             1
# Publishing                             1
# Investment Banking                     1
# Consumer Services                      1
# Athens, Ohio                           1
# Stillwater, ok                         1
# Berkeley, CA                           1
# Pittsburgh, Pennsylvania               1
# Tempe, AZ                              1
# Lawrence, KS                           1
# Wireless                               1
# Evanston, IL                           1
# ...

# %%
list1 = linkRaw1000['Industry'] #['denmark','kangaroo','dijeri dooo']
for x in list1:
    print(list1[list1.index(x)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-7fdcf4b8d53c> in <module>
#       1 list1 = linkRaw1000['Industry'] #['denmark','kangaroo','dijeri dooo']
#       2 for x in list1:
# ----> 3     print(list1[list1.index(x)])
#       4
#
# TypeError: 'RangeIndex' object is not callable

# %%
x = linkRaw1000['Industry'][0]
print(linkRaw1000['Industry'][linkRaw1000['Industry'].index(x)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-ac0e2a010f04> in <module>
#       1 x = linkRaw1000['Industry'][0]
# ----> 2 print(linkRaw1000['Industry'][linkRaw1000['Industry'].index(x)])
#
# TypeError: 'RangeIndex' object is not callable

# %%
linkRaw1000['Industry'].index(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-0b4a5a0cebe2> in <module>
# ----> 1 linkRaw1000['Industry'].index(x)
#
# TypeError: 'RangeIndex' object is not callable

# %%
x = 'consumer, electronics'

# %%
len(x)
# Out:
# 21

# %%
num = 3
if(num==3):
    print('yay')
else:
    print('no yay')
# Out:
# yay

# %%
x = 'blueville, West Virginia'
x.split(' ')
# Out:
# ['blueville,', 'West', 'Virginia']
