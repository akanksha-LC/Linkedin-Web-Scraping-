# %%
import pandas as pd
import numpy as np

# %%
linkRaw1000 = pd.read_csv('linkRaw1000.csv')

# %%
for x in range(len(linkRaw1000)):
    if(pd.isnull(linkRaw1000.Followers[x])):
        linkRaw1000.Followers[x] = linkRaw1000.Location[x]
        linkRaw1000.Location[x] = np.NaN
# Out:
# C:\Users\chattoa\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chattoa\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
print(linkRaw1000['Followers'].isnull().values.any())
print(linkRaw1000['Location'].isnull().values.any())
print(linkRaw1000['Industry'].isnull().values.any()) #bigFatLie
# Out:
# False
# True
# False

# %%
for x in linkRaw1000['Industry']:
    if isinstance(x, float):
        #print('Industrykkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk:', x)
for x in linkRaw1000['Location']:
    if isinstance(x, float):
        #print('Location:', x)
for x in linkRaw1000['Followers']:
    if isinstance(x, float):
        #print('Followerskkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk:', x)
# Out:
#   File "<ipython-input-84-8c11993bd36b>", line 4
#     for x in linkRaw1000['Location']:
#                                      ^
# IndentationError: expected an indented block

# %%
nan_loc = linkRaw1000[linkRaw1000.isna().any(axis=1)]
nan_loc.tail(10)
# Out:
#      Unnamed: 0                       Company                  Industry  \
# 929         929        Wayne State University               Detroit, mi
# 930         930      The University of Kansas              Lawrence, KS
# 931         931          Full Sail University           Winter Park, fl
# 932         932              UC Santa Barbara         Santa Barbara, CA
# 935         935              Brown University  Providence, Rhode Island
# 936         936  The University of New Mexico           Albuquerque, nm
# 948         948                       Technip              Oil & Energy
# 971         971                      Engadget              Online Media
# 976         976                  Alstom Power              Oil & Energy
# 983         983                           NHS    Hospital & Health Care
#
#     Location       Followers
# 929      NaN  181K followers
# 930      NaN  186K followers
# 931      NaN  120K followers
# 932      NaN  208K followers
# 935      NaN  132K followers
# 936      NaN  109K followers
# 948      NaN  660K followers
# 971      NaN  632K followers
# 976      NaN  382K followers
# 983      NaN  342K followers

# %%
nan_loc.head(9)
# Out:
#        Unnamed: 0                         Company  \
# Index
# 0               7                      ExxonMobil
# 1              12              UnitedHealth Group
# 2              26                         Foxconn
# 3             116                      Nationwide
# 4             131                        Generali
# 5             137              McKinsey & Company
# 6             138         Harvard Business Review
# 7             291  Indian Oil Corporation Limited
# 8             300              Harvard University
#
#                                 Industry                  Location  \
# Index
# 0                           Oil & Energy                       NaN
# 1                 Hospital & Health Care                       NaN
# 2      Information Technology & Services                       NaN
# 3                              Insurance                       NaN
# 4                              Insurance                       NaN
# 5                  Management Consulting                       NaN
# 6                             Publishing                       NaN
# 7                           Oil & Energy                       NaN
# 8                                    NaN  Cambridge, Massachusetts
#
#              Followers
# Index
# 0       2.1M followers
# 1       902K followers
# 2       173K followers
# 3       176K followers
# 4       316K followers
# 5       3.6M followers
# 6      11.3M followers
# 7       170K followers
# 8       1.5M followers

# %%
states_Cab = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
states_Cnames = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", "Wisconsin", "West Virginia", "Wyoming"]
states_NCab = [x.lower() for x in states_Cab]
states_NCnames = [x.lower() for x in states_Cnames]
states_list = states_Cab + states_Cnames + states_NCab + states_NCnames

# %%
indx = -1
num = 0
for x in nan_loc['Industry']:
    indx += 1
    if isinstance(x, float):
        num+=1
    else:
        if(len(x.split(', '))>=2):
            #print('here')
            x_list = x.split(', ')
            #print('jjjjjjjjjjjjjjjjjjj')
            for state in states_list:
                if(x_list[1]==state):
                    #print('lllllllllllllllllllll')
                    print(indx)
                    print(nan_loc.Location[indx])
                    nan_loc.Location[indx] = x
                    print(nan_loc.Location[indx])
                    nan_loc.Industry[indx] = np.NaN
# Out:
# 8
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-7437393e041f> in <module>
#      14                     #print('lllllllllllllllllllll')
#      15                     print(indx)
# ---> 16                     print(nan_loc.Location[indx])
#      17                     nan_loc.Location[indx] = x
#      18                     print(nan_loc.Location[indx])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 8

# %%
nan_loc.tail(10)
# Out:
#      Unnamed: 0                       Company                  Industry  \
# 929         929        Wayne State University               Detroit, mi
# 930         930      The University of Kansas              Lawrence, KS
# 931         931          Full Sail University           Winter Park, fl
# 932         932              UC Santa Barbara         Santa Barbara, CA
# 935         935              Brown University  Providence, Rhode Island
# 936         936  The University of New Mexico           Albuquerque, nm
# 948         948                       Technip              Oil & Energy
# 971         971                      Engadget              Online Media
# 976         976                  Alstom Power              Oil & Energy
# 983         983                           NHS    Hospital & Health Care
#
#     Location       Followers
# 929      NaN  181K followers
# 930      NaN  186K followers
# 931      NaN  120K followers
# 932      NaN  208K followers
# 935      NaN  132K followers
# 936      NaN  109K followers
# 948      NaN  660K followers
# 971      NaN  632K followers
# 976      NaN  382K followers
# 983      NaN  342K followers

# %%
print(range(0,135,1))
listmy = range(0, 136)
len(listmy)
# Out:
# range(0, 135)
# 136

# %%
nan_loc['Index'] = range(0, 136)
# Out:
# C:\Users\chattoa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
nan_loc = nan_loc.set_index(['Index'])

# %%
indx = -1
num = 0
for x in nan_loc['Industry']:
    indx += 1
    if isinstance(x, float):
        num+=1
    else:
        if(len(x.split(', '))>=2):
            x_list = x.split(', ')
            for state in states_list:
                if(x_list[1]==state):
                    nan_loc.Location[indx] = x
                    nan_loc.Industry[indx] = np.NaN
# Out:
# 8
# Cambridge, Massachusetts
# 11
# Stanford, CA
# 12
# Cambridge, ma
# 13
# Phoenix, AZ
# 14
# Ann Arbor, mi
# 16
# New York, NY
# 17
# Boston, MA
# 19
# Seattle, wa
# 20
# Los Angeles, CA
# 21
# Berkeley, CA
# 22
# Minneapolis and St. Paul, Minnesota
# 23
# New York, NY
# 25
# Cambridge, MA
# 26
# Los Angeles, CA
# 27
# Columbus, Ohio
# 28
# University Park, Pennsylvania
# 30
# Austin, tx
# 31
# Gainesville, Florida
# 33
# College Station, TX
# 34
# Baltimore, MD
# 35
# Tempe, AZ
# 36
# East Lansing, MI
# 37
# Philadelphia, PA
# 38
# Champaign, IL
# 39
# Ithaca, ny
# 40
# West Lafayette, in
# 41
# New Brunswick, NJ
# 42
# College Park, MD
# 43
# Madison, WI
# 45
# La Jolla, CA
# 47
# Evanston, IL
# 48
# Boston, MA
# 49
# Davis, California
# 50
# Pittsburgh, PA
# 51
# Baltimore, md
# 52
# Durham, North Carolina
# 53
# Provo, UT
# 54
# Raleigh, North Carolina
# 55
# Chapel Hill, NC
# 56
# Chicago, il
# 58
# Boston, ma
# 59
# Pittsburgh, PA
# 60
# Tucson, az
# 61
# Tampa, Florida
# 62
# Naperville, Illinois
# 63
# Lexington, KY
# 64
# Washington, dc
# 65
# Atlanta, ga
# 66
# Boston, MA
# 67
# Philadelphia, Pennsylvania
# 68
# Orlando, FL
# 69
# Fort Collins, co
# 71
# Nashville, Tennessee
# 72
# Tallahassee, fl
# 73
# Athens, GA
# 74
# Philadelphia, PA
# 75
# Cincinnati, Ohio
# 76
# Chicago, IL
# 77
# Blacksburg, VA
# 78
# Houston, tx
# 79
# Columbia, MO
# 80
# Bloomington, Indiana
# 81
# St. Louis, mo
# 82
# Miami, fl
# 83
# Stanford, CA
# 84
# Notre Dame, in
# 85
# Irvine, CA
# 86
# Ames, Iowa
# 87
# Boulder, Colorado
# 88
# Charlottesville, VA
# 89
# Atlanta, GA
# 90
# Columbia, SC
# 91
# 79409, tx
# 92
# Pittsburgh, Pennsylvania
# 93
# Princeton, NJ
# 94
# Tuscaloosa, al
# 95
# Washington, dc
# 96
# Syracuse, New York
# 97
# Stillwater, ok
# 98
# Clemson, SC
# 99
# Philadelphia, Pennsylvania
# 101
# Baton Rouge, la
# C:\Users\chattoa\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\chattoa\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 102
# Morgantown, wv
# 103
# San Diego, CA
# 104
# BIRMINGHAM, al
# 105
# Fairfax, va
# 106
# Athens, Ohio
# 107
# Buffalo, NY
# 108
# Iowa City, Iowa
# 109
# San Jose, CA
# 110
# Richardson, Texas
# 111
# Chicago, il
# 112
# Corvallis, or
# 113
# Kent, Ohio
# 114
# Rochester, NY
# 115
# Manhattan, KS
# 116
# Denton, tx
# 117
# Oxford, OH
# 118
# Auburn, AL
# 119
# Pullman/Spokane/Tri-Cities/Vancouver/Everett/Global, Washington
# 120
# Storrs, CT
# 121
# Cambridge, MA
# 122
# Amherst, Massachusetts
# 123
# Norman, Oklahoma
# 124
# Eugene, OR
# 125
# Newark, DE
# 126
# Detroit, mi
# 127
# Lawrence, KS
# 128
# Winter Park, fl
# 129
# Santa Barbara, CA
# 130
# Providence, Rhode Island
# 131
# Albuquerque, nm

# %%
nan_loc.head(60)
# Out:
#        Unnamed: 0                                      Company  \
# Index
# 0               7                                   ExxonMobil
# 1              12                           UnitedHealth Group
# 2              26                                      Foxconn
# 3             116                                   Nationwide
# 4             131                                     Generali
# 5             137                           McKinsey & Company
# 6             138                      Harvard Business Review
# 7             291               Indian Oil Corporation Limited
# 8             300                           Harvard University
# 9             372                                      Fujitsu
# 10            392          United States Department of Defense
# 11            400                          Stanford University
# 12            454        Massachusetts Institute of Technology
# 13            462                        University of Phoenix
# 14            480                       University of Michigan
# 15            501                                      Safeway
# 16            509  Columbia University in the City of New York
# 17            526                      Harvard Business School
# 18            529                                       Subway
# 19            530                     University of Washington
# 20            550            University of Southern California
# 21            551           University of California, Berkeley
# 22            555                      University of Minnesota
# 23            560                          New York University
# 24            571                              Banco do Brasil
# 25            573                                          edX
# 26            581        University of California, Los Angeles
# 27            587                    The Ohio State University
# 28            594                        Penn State University
# 29            607                                        Chubb
# 30            612            The University of Texas at Austin
# 31            620                        University of Florida
# 32            624                                MAC Cosmetics
# 33            638                         Texas A&M University
# 34            641          Laureate International Universities
# 35            648                     Arizona State University
# 36            654                    Michigan State University
# 37            679                   University of Pennsylvania
# 38            681   University of Illinois at Urbana-Champaign
# 39            686                           Cornell University
# 40            688                            Purdue University
# 41            689                           Rutgers University
# 42            716                       University of Maryland
# 43            720              University of Wisconsin-Madison
# 44            730                                 Carrier HVAC
# 45            743                                 UC San Diego
# 46            753              Georgia Institute of Technology
# 47            758                      Northwestern University
# 48            768                            Boston University
# 49            769              University of California, Davis
# 50            777                     University of Pittsburgh
# 51            785                 The Johns Hopkins University
# 52            786                              Duke University
# 53            789                     Brigham Young University
# 54            790              North Carolina State University
# 55            793  University of North Carolina at Chapel Hill
# 56            794               University of Illinois Chicago
# 57            795                            Otis Elevator Co.
# 58            796                       Harvard Medical School
# 59            800                   Carnegie Mellon University
#
#                                    Industry  \
# Index
# 0                              Oil & Energy
# 1                    Hospital & Health Care
# 2         Information Technology & Services
# 3                                 Insurance
# 4                                 Insurance
# 5                     Management Consulting
# 6                                Publishing
# 7                              Oil & Energy
# 8                                       NaN
# 9         Information Technology & Services
# 10                                 Military
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                   Retail
# 16                                      NaN
# 17                                      NaN
# 18                              Restaurants
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                  Banking
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                Insurance
# 30                                      NaN
# 31                                      NaN
# 32                                Cosmetics
# 33                                      NaN
# 34                                      NaN
# 35                                      NaN
# 36                                      NaN
# 37                                      NaN
# 38                                      NaN
# 39                                      NaN
# 40                                      NaN
# 41                                      NaN
# 42                                      NaN
# 43                                      NaN
# 44     Mechanical Or Industrial Engineering
# 45                                      NaN
# 46                        Atlanta, Georgia
# 47                                      NaN
# 48                                      NaN
# 49                                      NaN
# 50                                      NaN
# 51                                      NaN
# 52                                      NaN
# 53                                      NaN
# 54                                      NaN
# 55                                      NaN
# 56                                      NaN
# 57                        Consumer Services
# 58                                      NaN
# 59                                      NaN
#
#                                   Location        Followers
# Index
# 0                                      NaN   2.1M followers
# 1                                      NaN   902K followers
# 2                                      NaN   173K followers
# 3                                      NaN   176K followers
# 4                                      NaN   316K followers
# 5                                      NaN   3.6M followers
# 6                                      NaN  11.3M followers
# 7                                      NaN   170K followers
# 8                 Cambridge, Massachusetts   1.5M followers
# 9                                      NaN   335K followers
# 10                                     NaN   704K followers
# 11                            Stanford, CA   811K followers
# 12                           Cambridge, ma   855K followers
# 13                             Phoenix, AZ   928K followers
# 14                           Ann Arbor, mi   518K followers
# 15                                     NaN   157K followers
# 16                            New York, NY   440K followers
# 17                              Boston, MA   1.2M followers
# 18                                     NaN   195K followers
# 19                             Seattle, wa   499K followers
# 20                         Los Angeles, CA   476K followers
# 21                            Berkeley, CA   696K followers
# 22     Minneapolis and St. Paul, Minnesota   395K followers
# 23                            New York, NY   653K followers
# 24                                     NaN   1.1M followers
# 25                           Cambridge, MA   259K followers
# 26                         Los Angeles, CA   705K followers
# 27                          Columbus, Ohio   474K followers
# 28           University Park, Pennsylvania   606K followers
# 29                                     NaN   431K followers
# 30                              Austin, tx   526K followers
# 31                    Gainesville, Florida   438K followers
# 32                                     NaN   180K followers
# 33                     College Station, TX   474K followers
# 34                           Baltimore, MD   250K followers
# 35                               Tempe, AZ   573K followers
# 36                        East Lansing, MI   452K followers
# 37                        Philadelphia, PA   330K followers
# 38                           Champaign, IL   432K followers
# 39                              Ithaca, ny   437K followers
# 40                      West Lafayette, in   395K followers
# 41                       New Brunswick, NJ   382K followers
# 42                        College Park, MD   384K followers
# 43                             Madison, WI   361K followers
# 44                                     NaN   257K followers
# 45                            La Jolla, CA   301K followers
# 46                                     NaN   314K followers
# 47                            Evanston, IL   261K followers
# 48                              Boston, MA   380K followers
# 49                       Davis, California   275K followers
# 50                          Pittsburgh, PA   224K followers
# 51                           Baltimore, md   211K followers
# 52                  Durham, North Carolina   215K followers
# 53                               Provo, UT   270K followers
# 54                 Raleigh, North Carolina   271K followers
# 55                         Chapel Hill, NC   278K followers
# 56                             Chicago, il   221K followers
# 57                                     NaN   190K followers
# 58                              Boston, ma   160K followers
# 59                          Pittsburgh, PA   204K followers
